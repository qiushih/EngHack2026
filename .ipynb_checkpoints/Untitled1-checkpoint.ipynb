# %%
import pandas as pd

# %%
df =  pd.read_csv('Data sets - Spatial Data.csv')

# %%
df = df.drop(0)

# %%
df['X'] = pd.to_numeric(df['X'])

# %%
df['Y'] = pd.to_numeric(df['Y'])

# %%
df['Depth'] = pd.to_numeric(df['Depth'])

# %%
df['Baseline CH4 Production Rate'] = pd.to_numeric(df['Baseline CH4 Production Rate'])

# %%
df = df.drop(columns=['Solids'])

# %%
df = df.drop(columns=['Clay'])

# %%
df
# Out:
#             X        Y  Depth Baseline DOC   Baseline CH4 Production Rate
# 1     2102.04  2494.52   4.43        110.03                       0.01555
# 2     1228.38  1526.66   5.13        100.35                       0.01284
# 3     2341.64    84.27   4.22        112.63                       0.01513
# 4     2295.25  2025.14   4.91         98.28                       0.01082
# 5      523.82  1233.80   4.25        122.08                       0.02335
# ...       ...      ...    ...           ...                           ...
# 996   1521.96  1962.64   4.39        113.78                       0.02184
# 997   1541.31   180.15   4.25        116.59                       0.01207
# 998    147.14   127.54   4.42         98.44                       0.01957
# 999    803.18    28.77   5.27        101.64                       0.01953
# 1000  1078.13  2286.08   2.95        107.58                       0.02012
#
# [1000 rows x 5 columns]

# %%
df['Mass/kg'] = df['Depth'] * df['Baseline CH4 Production Rate']
# Out:
# /var/folders/df/rktw50pn5j997552bbp9t1s40000gn/T/ipykernel_49549/917476962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mass/kg'] = df['Depth'] * df['Baseline CH4 Production Rate']

# %%
df
# Out:
#             X        Y  Depth Baseline DOC   Baseline CH4 Production Rate  \
# 1     2102.04  2494.52   4.43        110.03                       0.01555
# 2     1228.38  1526.66   5.13        100.35                       0.01284
# 3     2341.64    84.27   4.22        112.63                       0.01513
# 4     2295.25  2025.14   4.91         98.28                       0.01082
# 5      523.82  1233.80   4.25        122.08                       0.02335
# ...       ...      ...    ...           ...                           ...
# 996   1521.96  1962.64   4.39        113.78                       0.02184
# 997   1541.31   180.15   4.25        116.59                       0.01207
# 998    147.14   127.54   4.42         98.44                       0.01957
# 999    803.18    28.77   5.27        101.64                       0.01953
# 1000  1078.13  2286.08   2.95        107.58                       0.02012
#
#             Mass/kg
# 1     361211.930212
# 2     123525.736639
# 3      12599.244417
# 4     246941.340171
# 5      64136.116149
# ...             ...
# 996   286392.103050
# 997    14243.622753
# 998     1623.268120
# 999     2378.294360
# 1000  146289.295160
#
# [1000 rows x 6 columns]

# %%
df['Energy/MJ']= 55.5 * 0.37 * df['Mass/kg']

# %%
df
# Out:
#             X        Y  Depth Baseline DOC   Baseline CH4 Production Rate  \
# 1     2102.04  2494.52   4.43        110.03                       0.01555
# 2     1228.38  1526.66   5.13        100.35                       0.01284
# 3     2341.64    84.27   4.22        112.63                       0.01513
# 4     2295.25  2025.14   4.91         98.28                       0.01082
# 5      523.82  1233.80   4.25        122.08                       0.02335
# ...       ...      ...    ...           ...                           ...
# 996   1521.96  1962.64   4.39        113.78                       0.02184
# 997   1541.31   180.15   4.25        116.59                       0.01207
# 998    147.14   127.54   4.42         98.44                       0.01957
# 999    803.18    28.77   5.27        101.64                       0.01953
# 1000  1078.13  2286.08   2.95        107.58                       0.02012
#
#             Mass/kg     Energy/MJ
# 1     361211.930212  7.417487e+06
# 2     123525.736639  2.536601e+06
# 3      12599.244417  2.587255e+05
# 4     246941.340171  5.070940e+06
# 5      64136.116149  1.317035e+06
# ...             ...           ...
# 996   286392.103050  5.881062e+06
# 997    14243.622753  2.924928e+05
# 998     1623.268120  3.333381e+04
# 999     2378.294360  4.883827e+04
# 1000  146289.295160  3.004051e+06
#
# [1000 rows x 7 columns]

# %%
df = df.sort_values(by='Mass/kg', ascending=False)

# %%
df
# Out:
#            X        Y  Depth Baseline DOC   Baseline CH4 Production Rate  \
# 498  2443.23  2400.83   4.63         99.24                       0.02707
# 592  2453.81  2056.89   6.56        123.39                       0.02095
# 856  1931.55  2377.32   5.14        111.77                       0.02894
# 841  2483.06  1823.52   5.38        112.92                       0.02573
# 657  2185.25  2434.95   5.17        103.77                       0.02259
# ..       ...      ...    ...           ...                           ...
# 596  1529.26  2414.63   4.75        114.39                       0.01929
# 910  1488.67  2132.23   4.51        112.23                       0.02359
# 397  1355.87  1638.37   5.95        102.94                       0.02545
# 197  1638.71  2183.65   5.36        106.22                       0.01751
# 738  1603.44  1596.66   5.41         92.95                       0.02414
#
#            Mass/kg     Energy/MJ
# 498  735182.242171  1.509697e+07
# 592  693649.161226  1.424409e+07
# 856  683054.323402  1.402652e+07
# 841  626786.749376  1.287107e+07
# 657  621438.206687  1.276123e+07
# ..             ...           ...
# 596  338343.438380  6.947883e+06
# 910  337704.594048  6.934764e+06
# 397  336383.582170  6.907637e+06
# 197  335842.821366  6.896532e+06
# 738  334348.739072  6.865851e+06
#
# [100 rows x 7 columns]

# %%
df = df.head(100)

# %%
df.to_csv('CH4_Emissions_Analysis.csv', index=False, encoding='utf_8_sig')

# %%
from IPython.display import FileLink
FileLink('CH4_Emissions_Analysis.csv')
# Out:
# /Users/huangqiushi/Developer/CH4_Emissions_Analysis.csv

# %%
df
# Out:
#            X        Y  Depth Baseline DOC   Baseline CH4 Production Rate  \
# 498  2443.23  2400.83   4.63         99.24                       0.02707
# 592  2453.81  2056.89   6.56        123.39                       0.02095
# 856  1931.55  2377.32   5.14        111.77                       0.02894
# 841  2483.06  1823.52   5.38        112.92                       0.02573
# 657  2185.25  2434.95   5.17        103.77                       0.02259
# ..       ...      ...    ...           ...                           ...
# 596  1529.26  2414.63   4.75        114.39                       0.01929
# 910  1488.67  2132.23   4.51        112.23                       0.02359
# 397  1355.87  1638.37   5.95        102.94                       0.02545
# 197  1638.71  2183.65   5.36        106.22                       0.01751
# 738  1603.44  1596.66   5.41         92.95                       0.02414
#
#            Mass/kg     Energy/MJ
# 498  735182.242171  1.509697e+07
# 592  693649.161226  1.424409e+07
# 856  683054.323402  1.402652e+07
# 841  626786.749376  1.287107e+07
# 657  621438.206687  1.276123e+07
# ..             ...           ...
# 596  338343.438380  6.947883e+06
# 910  337704.594048  6.934764e+06
# 397  336383.582170  6.907637e+06
# 197  335842.821366  6.896532e+06
# 738  334348.739072  6.865851e+06
#
# [100 rows x 7 columns]

# %%
total_energy = df['Energy/MJ'].sum()

# %%
total_energy
# Out:
# np.float64(856101879.4567835)

# %%
df['Mass/kg'].sum()
# Out:
# np.float64(41689889.43057139)
